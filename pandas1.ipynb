# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import parallel_coordinates

tabla = pd.read_excel('balance.xlsx')

# %%
print(tabla['Период'])
print(tabla['Основные средства'])
print(tabla['Запасы'])
# Out:
# 0    2010
# 1    2011
# 2    2012
# Name: Период, dtype: int64
# 0    137101
# 1    259228
# 2    171694
# Name: Основные средства, dtype: int64
# 0     85022
# 1    309331
# 2    187098
# Name: Запасы, dtype: int64

# %%
x = tabla['Период']
y = tabla['Основные средства']
z = tabla['Запасы']
plt.grid()
plt.show
plt.plot(x, y)
plt.plot(x, z)
